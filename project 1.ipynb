# %% [markdown]
# # IPL 2023 AUCTION DATA ANALYSIS

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### LOADING DATA

# %%
df=pd.read_csv("D:\\data analytics\\csv and exl files\\iplauction2023.csv")
df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df.shape
# Out:
# (309, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
df.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
df.dropna()
# Out:
#                 name player style  nationality  base price (in lacs)  \
# 3    Shakib Al Hasan   Allrounder   Bangladesh                 150.0
# 4           Joe Root       Batter      England                 100.0
# 5       Abdul Basith   Allrounder        India                  20.0
# 7       Akeal Hosein       Bowler  West Indies                 100.0
# 8       Raghav Goyal       Bowler        India                  20.0
# ..               ...          ...          ...                   ...
# 147       Ben Stokes   Allrounder      England                 200.0
# 148    Cameron Green   Allrounder    Australia                 200.0
# 149    Sikandar Raza   Allrounder     Zimbabwe                  50.0
# 150       Sam Curran   Allrounder      England                 200.0
# 151      Harry Brook       Batter      England                 150.0
#
#      final price (in lacs) franchise status
# 3                    150.0       KKR   SOLD
# 4                    100.0        RR   SOLD
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### PRINT FIRST 10 VALUES

# %%
df.head(10)
# Out:
#                    name player style   nationality  base price (in lacs)  \
# 0          Harshit Rana       Bowler         India                   NaN
# 1             Ekant Sen       Batter         India                  20.0
# 2         Wayne Parnell   Allrounder  South Africa                  75.0
# 3       Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4              Joe Root       Batter       England                 100.0
# 5          Abdul Basith   Allrounder         India                  20.0
# 6       Prashant Chopra   Allrounder         India                  20.0
# 7          Akeal Hosein       Bowler   West Indies                 100.0
# 8          Raghav Goyal       Bowler         India                  20.0
# 9  Yudhvir Singh Charak   Allrounder         India                  20.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# ...

# %%
df["status"].value_counts()
# Out:
# status
# RETAINED    158
# SOLD         80
# UNSOLD       71
# Name: count, dtype: int64

# %% [markdown]
# ### FRANCHISE WISE RETAINED PLAYERS

# %%
df.loc[(df["status"]=="RETAINED"),["name","player style","franchise","final price (in lacs)","status"]].sort_values(by="franchise",ascending=False).reset_index()
# Out:
#      index                 name player style franchise  final price (in lacs)  \
# 0      176     Fazalhaq Farooqi       Bowler       SRH                   50.0
# 1      277          Umran Malik       Bowler       SRH                  400.0
# 2      253         Marco Jansen   Allrounder       SRH                  420.0
# 3      278          Abdul Samad   Allrounder       SRH                  400.0
# 4      196       Glenn Phillips    WK-Batter       SRH                  150.0
# ..     ...                  ...          ...       ...                    ...
# 153    228        Ambati Rayudu    WK-Batter       CSK                  675.0
# 154    205         Devon Conway       Batter       CSK                  100.0
# 155    206     Prashant Solanki       Bowler       CSK                  120.0
# 156    211      Simarjeet Singh       Bowler       CSK                   20.0
# 157    173  Subhranshu Senapati       Batter       CSK                   20.0
#
#        status
# 0    RETAINED
# ...

# %%
df.loc[(df["status"]=="RETAINED"),["franchise"]].value_counts()
# Out:
# franchise
# DC           19
# CSK          18
# GT           18
# RCB          18
# PBKS         16
# RR           16
# LSG          15
# MI           15
# SRH          12
# KKR          11
# Name: count, dtype: int64

# %% [markdown]
# ### PURCHASED PLAYERS(FRANCHISE WISE)

# %% [markdown]
# ##### KKR (KOLKATA KNIGHT RIDER)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="KKR"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index                name player style franchise  base price (in lacs)  \
# 0      3     Shakib Al Hasan   Allrounder       KKR                 150.0
# 1     51         David Wiese   Allrounder       KKR                 100.0
# 2    105        N Jagadeesan    WK-Batter       KKR                  20.0
# 3    109       Vaibhav Arora   Allrounder       KKR                  20.0
# 4     18       Mandeep Singh       Batter       KKR                  50.0
# 5     25          Litton Das    WK-Batter       KKR                  50.0
# 6     40  Kulwant Khejroliya       Bowler       KKR                  20.0
# 7     60       Suyash Sharma       Bowler       KKR                  20.0
#
#    final price (in lacs)
# 0                  150.0
# 1                  100.0
# 2                   90.0
# 3                   60.0
# 4                   50.0
# 5                   50.0
# 6                   20.0
# 7                   20.0

# %% [markdown]
# ##### CSK(CHENNAI SUPER KINGS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="CSK"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index               name player style franchise  base price (in lacs)  \
# 0    147         Ben Stokes   Allrounder       CSK                 200.0
# 1     80      Kyle Jamieson   Allrounder       CSK                 100.0
# 2    116     Nishant Sindhu   Allrounder       CSK                  20.0
# 3    130     Ajinkya Rahane       Batter       CSK                  50.0
# 4     29      Bhagath Varma   Allrounder       CSK                  20.0
# 5     39  Ajay Jadav Mandal   Allrounder       CSK                  20.0
# 6    124      Shaik Rasheed       Batter       CSK                  20.0
#
#    final price (in lacs)
# 0                 1625.0
# 1                  100.0
# 2                   60.0
# 3                   50.0
# 4                   20.0
# 5                   20.0
# 6                   20.0

# %% [markdown]
# ##### RR (RAJESTHAN ROYALS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="RR"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index                 name player style franchise  base price (in lacs)  \
# 0    132         Jason Holder   Allrounder        RR                 200.0
# 1     23           Adam Zampa       Bowler        RR                 150.0
# 2      4             Joe Root       Batter        RR                 100.0
# 3     70     Donavon Ferreira    WK-Batter        RR                  20.0
# 4     20              KM Asif       Bowler        RR                  30.0
# 5      5         Abdul Basith   Allrounder        RR                  20.0
# 6     14        Akash Vashist   Allrounder        RR                  20.0
# 7     19       Murugan Ashwin       Bowler        RR                  20.0
# 8     38  Kunal Singh Rathore    WK-Batter        RR                  20.0
#
#    final price (in lacs)
# 0                  575.0
# 1                  150.0
# 2                  100.0
# 3                   50.0
# 4                   30.0
# 5                   20.0
# 6                   20.0
# ...

# %% [markdown]
# ##### SRH(SUNRISE HYDRABAD)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="SRH"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#     index              name player style franchise  base price (in lacs)  \
# 0     151       Harry Brook       Batter       SRH                 150.0
# 1     131    Mayank Agarwal       Batter       SRH                 100.0
# 2     146  Heinrich Klaasen    WK-Batter       SRH                 100.0
# 3     122    Vivrant Sharma   Allrounder       SRH                  20.0
# 4     139       Adil Rashid       Bowler       SRH                 200.0
# 5      74      Mayank Dagar   Allrounder       SRH                  20.0
# 6       7      Akeal Hosein       Bowler       SRH                 100.0
# 7     135   Mayank Markande       Bowler       SRH                  50.0
# 8     111     Upendra Yadav    WK-Batter       SRH                  20.0
# 9      22  Anmolpreet Singh       Batter       SRH                  20.0
# 10     48      Nitish Reddy    WK-Batter       SRH                  20.0
# 11    113      Sanvir Singh   Allrounder       SRH                  20.0
# ...

# %% [markdown]
# ##### MI (MUMBAI INDIANS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="MI"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index             name player style franchise  base price (in lacs)  \
# 0    148    Cameron Green   Allrounder        MI                 200.0
# 1    140  Jhye Richardson       Bowler        MI                 150.0
# 2     78    Piyush Chawla       Bowler        MI                  50.0
# 3      8     Raghav Goyal       Bowler        MI                  20.0
# 4     30    Nehal Wadhera   Allrounder        MI                  20.0
# 5     54     Shams Mulani   Allrounder        MI                  20.0
# 6     66     Vishnu Vinod    WK-Batter        MI                  20.0
# 7     73      Duan Jansen   Allrounder        MI                  20.0
#
#    final price (in lacs)
# 0                 1750.0
# 1                  150.0
# 2                   50.0
# 3                   20.0
# 4                   20.0
# 5                   20.0
# 6                   20.0
# 7                   20.0

# %% [markdown]
# ##### LSG (LUCKNOW SUPER GAINTS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="LSG"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index                  name player style franchise  base price (in lacs)  \
# 0    136       Nicholas Pooran    WK-Batter       LSG                 200.0
# 1     89           Daniel Sams   Allrounder       LSG                  75.0
# 2     12         Naveen-ul-Haq   Allrounder       LSG                  50.0
# 3     79           Amit Mishra       Bowler       LSG                  50.0
# 4     91      Romario Shepherd       Bowler       LSG                  50.0
# 5    134        Jaydev Unadkat       Bowler       LSG                  50.0
# 6    108           Yash Thakur       Bowler       LSG                  20.0
# 7      9  Yudhvir Singh Charak   Allrounder       LSG                  20.0
# 8     53         Swapnil Singh   Allrounder       LSG                  20.0
# 9     72         Prerak Mankad   Allrounder       LSG                  20.0
#
#    final price (in lacs)
# 0                 1600.0
# 1                   75.0
# 2                   50.0
# 3                   50.0
# ...

# %% [markdown]
# ##### DC (DELHI CAPITALS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="DC"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index           name player style franchise  base price (in lacs)  \
# 0    103   Mukesh Kumar       Bowler        DC                  20.0
# 1     26  Rilee Rossouw       Batter        DC                 200.0
# 2     96  Manish Pandey       Batter        DC                 100.0
# 3    144    Philip Salt       Batter        DC                 200.0
# 4    133  Ishant Sharma       Bowler        DC                  50.0
#
#    final price (in lacs)
# 0                  550.0
# 1                  460.0
# 2                  240.0
# 3                  200.0
# 4                   50.0

# %% [markdown]
# ##### PBKS(PUNJAB KINGS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="PBKS"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index                   name player style franchise  base price (in lacs)  \
# 0    150             Sam Curran   Allrounder      PBKS                 200.0
# 1    149          Sikandar Raza   Allrounder      PBKS                  50.0
# 2     77  Harpreet Singh Bhatia       Batter      PBKS                  20.0
# 3     27           Shivam Singh   Allrounder      PBKS                  20.0
# 4     28           Mohit Rathee   Allrounder      PBKS                  20.0
# 5     65     Vidhwath Kaverappa       Bowler      PBKS                  20.0
#
#    final price (in lacs)
# 0                 1850.0
# 1                   50.0
# 2                   40.0
# 3                   20.0
# 4                   20.0
# 5                   20.0

# %% [markdown]
# ##### GT (GUJRAT TITANS)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="GT"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index             name player style franchise  base price (in lacs)  \
# 0    104      Shivam Mavi       Bowler        GT                  40.0
# 1     57    Joshua Little       Bowler        GT                  50.0
# 2    129  Kane Williamson       Batter        GT                 200.0
# 3    112    Srikar Bharat    WK-Batter        GT                  20.0
# 4     56     Mohit Sharma       Bowler        GT                  50.0
# 5    127      Odean Smith   Allrounder        GT                  50.0
# 6     68      Urvil Patel    WK-Batter        GT                  20.0
#
#    final price (in lacs)
# 0                  600.0
# 1                  440.0
# 2                  200.0
# 3                  120.0
# 4                   50.0
# 5                   50.0
# 6                   20.0

# %% [markdown]
# ##### RCB (ROYAL CHALLENGE BANGALORE)

# %%
df.loc[(df["status"]=="SOLD")&(df["franchise"]=="RCB"),["name","player style","franchise","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
# Out:
#    index             name player style franchise  base price (in lacs)  \
# 0     94       Will Jacks   Allrounder       RCB                 150.0
# 1    142     Reece Topley       Bowler       RCB                  75.0
# 2     64      Rajan Kumar       Bowler       RCB                  20.0
# 3     47    Avinash Singh       Bowler       RCB                  20.0
# 4     32       Sonu Yadav   Allrounder       RCB                  20.0
# 5     75   Manoj Bhandage   Allrounder       RCB                  20.0
# 6     98  Himanshu Sharma       Bowler       RCB                  20.0
#
#    final price (in lacs)
# 0                  320.0
# 1                  190.0
# 2                   70.0
# 3                   60.0
# 4                   20.0
# 5                   20.0
# 6                   20.0

# %% [markdown]
# ### TOTAL PLAYER PURCHASE BY FRANCHISE

# %%
df.loc[(df["status"]=="SOLD"),["franchise"]].value_counts().reset_index()
# Out:
#   franchise  count
# 0       SRH     13
# 1       LSG     10
# 2        RR      9
# 3       KKR      8
# 4        MI      8
# 5       CSK      7
# 6        GT      7
# 7       RCB      7
# 8      PBKS      6
# 9        DC      5

# %%
df.loc[(df["status"]=="SOLD"),["franchise"]].value_counts().plot(x="franchise",y="count",kind="bar",title="TOTAL PLAYER PURCHASE BY FRANCHISE")
# Out:
# <Axes: title={'center': 'TOTAL PLAYER PURCHASE BY FRANCHISE'}, xlabel='franchise'>

# %% [markdown]
# ### TOTAL FRANCHISE PLAYERS COUNT FOR IPL 2023

# %%
df["franchise"].value_counts().reset_index()
# Out:
#   franchise  count
# 0        RR     25
# 1       SRH     25
# 2       LSG     25
# 3       CSK     25
# 4       RCB     25
# 5        GT     25
# 6        DC     24
# 7        MI     23
# 8      PBKS     22
# 9       KKR     19

# %%
df["franchise"].value_counts().plot(x="franchise",y="count",kind="bar",color="green",title="TOTAL PLAYERS COUNT BY THEIR FRANCHISE")
# Out:
# <Axes: title={'center': 'TOTAL PLAYERS COUNT BY THEIR FRANCHISE'}, xlabel='franchise'>

# %% [markdown]
# ### FRANCHISE WISE HIGHEST PAID PLAYER IN IPL 2023

# %%
df.loc[df.groupby("franchise")["final price (in lacs)"].idxmax().values,["name","franchise","final price (in lacs)","status"]]
# Out:
#               name franchise  final price (in lacs)    status
# 147     Ben Stokes       CSK                 1625.0      SOLD
# 307   Rishabh Pant        DC                 1600.0  RETAINED
# 300    Rashid Khan        GT                 1500.0  RETAINED
# 272   Shreyas Iyer       KKR                 1225.0  RETAINED
# 292       KL Rahul       LSG                 1700.0  RETAINED
# 148  Cameron Green        MI                 1750.0      SOLD
# 150     Sam Curran      PBKS                 1850.0      SOLD
# 282    Virat Kohli       RCB                 1500.0  RETAINED
# 285   Sanju Samson        RR                 1400.0  RETAINED
# 151    Harry Brook       SRH                 1325.0      SOLD

# %% [markdown]
# ### UNSOLD PLAYERS IN IPL 2023

# %%
df.loc[(df["status"]=="UNSOLD"),["name","player style","base price (in lacs)"]].reset_index()
# Out:
#     index                name player style  base price (in lacs)
# 0       1           Ekant Sen       Batter                  20.0
# 1       2       Wayne Parnell   Allrounder                  75.0
# 2       6     Prashant Chopra   Allrounder                  20.0
# 3      10           Luke Wood       Bowler                 100.0
# 4      11  Dilshan Madushanka       Bowler                  50.0
# ..    ...                 ...          ...                   ...
# 66    137    Mujeeb Ur Rahman       Bowler                 100.0
# 67    138      Tabraiz Shamsi       Bowler                 100.0
# 68    141          Adam Milne       Bowler                 200.0
# 69    143        Chris Jordan       Bowler                 200.0
# 70    145          Tom Banton    WK-Batter                 200.0
#
# [71 rows x 4 columns]

# %% [markdown]
# ### HIGHEST PAID BATSMAN SOLD IN IPL 2023

# %%
df.loc[(df["status"]=="SOLD")&(df["player style"]=="Batter"),["name","player style","franchise","nationality","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index().head(5)
# Out:
#    index             name player style franchise   nationality  \
# 0    151      Harry Brook       Batter       SRH       England
# 1    131   Mayank Agarwal       Batter       SRH         India
# 2     26    Rilee Rossouw       Batter        DC  South Africa
# 3     96    Manish Pandey       Batter        DC         India
# 4    129  Kane Williamson       Batter        GT   New Zealand
#
#    base price (in lacs)  final price (in lacs)
# 0                 150.0                 1325.0
# 1                 100.0                  825.0
# 2                 200.0                  460.0
# 3                 100.0                  240.0
# 4                 200.0                  200.0

# %% [markdown]
# ### HIGHEST PAID BOWLER SOLD IN IPL 2023

# %%
df.loc[(df["status"]=="SOLD")&(df["player style"]=="Bowler"),["name","player style","franchise","nationality","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index().head(5)
# Out:
#    index           name player style franchise nationality  \
# 0    104    Shivam Mavi       Bowler        GT       India
# 1    103   Mukesh Kumar       Bowler        DC       India
# 2     57  Joshua Little       Bowler        GT     Ireland
# 3    139    Adil Rashid       Bowler       SRH     England
# 4    142   Reece Topley       Bowler       RCB     England
#
#    base price (in lacs)  final price (in lacs)
# 0                  40.0                  600.0
# 1                  20.0                  550.0
# 2                  50.0                  440.0
# 3                 200.0                  200.0
# 4                  75.0                  190.0

# %% [markdown]
# ### HIGHEST PAID ALLROUNDER SOLD IN IPL 2023

# %%
df.loc[(df["status"]=="SOLD")&(df["player style"]=="Allrounder"),["name","player style","franchise","nationality","base price (in lacs)","final price (in lacs)"]].sort_values(by="final price (in lacs)",ascending=False).reset_index().head(5)
# Out:
#    index           name player style franchise  nationality  \
# 0    150     Sam Curran   Allrounder      PBKS      England
# 1    148  Cameron Green   Allrounder        MI    Australia
# 2    147     Ben Stokes   Allrounder       CSK      England
# 3    132   Jason Holder   Allrounder        RR  West Indies
# 4     94     Will Jacks   Allrounder       RCB      England
#
#    base price (in lacs)  final price (in lacs)
# 0                 200.0                 1850.0
# 1                 200.0                 1750.0
# 2                 200.0                 1625.0
# 3                 200.0                  575.0
# 4                 150.0                  320.0

# %% [markdown]
# ### OVERALL HIGHEST PAID PLAYER OF IPL 2023

# %%
df.sort_values("final price (in lacs)",ascending=False).reset_index().head(5)
# Out:
#    index             name player style nationality  base price (in lacs)  \
# 0    150       Sam Curran   Allrounder     England                 200.0
# 1    148    Cameron Green   Allrounder   Australia                 200.0
# 2    292         KL Rahul    WK-Batter       India                   NaN
# 3    147       Ben Stokes   Allrounder     England                 200.0
# 4    296  Ravindra Jadeja   Allrounder       India                   NaN
#
#    final price (in lacs) franchise    status
# 0                 1850.0      PBKS      SOLD
# 1                 1750.0        MI      SOLD
# 2                 1700.0       LSG  RETAINED
# 3                 1625.0       CSK      SOLD
# 4                 1600.0       CSK  RETAINED

# %%
df.sort_values("final price (in lacs)",ascending=False).reset_index().head(5).plot(x="name",y="final price (in lacs)",kind="bar",title="HIGEST PAID PLAYER IN IPL 2023")
# Out:
# <Axes: title={'center': 'HIGEST PAID PLAYER IN IPL 2023'}, xlabel='name'>

# %% [markdown]
# ### TOP 5 HIGHEST INDIAN PLAYER IN IPL 2023

# %%
higest_player=df.loc[(df["nationality"]=="India"),["name","player style","franchise","final price (in lacs)","status"]].sort_values(by="final price (in lacs)",ascending=False).reset_index()
higest_player.head(5)
# Out:
#    index             name player style franchise  final price (in lacs)  \
# 0    292         KL Rahul    WK-Batter       LSG                 1700.0
# 1    290     Rohit Sharma       Batter        MI                 1600.0
# 2    307     Rishabh Pant    WK-Batter        DC                 1600.0
# 3    296  Ravindra Jadeja   Allrounder       CSK                 1600.0
# 4    230     Ishan Kishan    WK-Batter        MI                 1525.0
#
#      status
# 0  RETAINED
# 1  RETAINED
# 2  RETAINED
# 3  RETAINED
# 4  RETAINED

# %%
higest_player.head(5).plot(x="name",y="final price (in lacs)",kind="bar",title="TOP 5 HIGHEST INDIAN PLAYER IN IPL 2023")
# Out:
# <Axes: title={'center': 'TOP 5 HIGHEST INDIAN PLAYER IN IPL 2023'}, xlabel='name'>
